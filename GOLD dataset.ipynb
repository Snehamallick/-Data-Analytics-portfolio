# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

# %%
gold_data=pd.read_csv('gld_price_data.csv')

# %%
gold_data
# Out:
#            Date          SPX         GLD        USO      SLV   EUR/USD
# 0      1/2/2008  1447.160034   84.860001  78.470001  15.1800  1.471692
# 1      1/3/2008  1447.160034   85.570000  78.370003  15.2850  1.474491
# 2      1/4/2008  1411.630005   85.129997  77.309998  15.1670  1.475492
# 3      1/7/2008  1416.180054   84.769997  75.500000  15.0530  1.468299
# 4      1/8/2008  1390.189941   86.779999  76.059998  15.5900  1.557099
# ...         ...          ...         ...        ...      ...       ...
# 2285   5/8/2018  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 6 columns]

# %%
gold_data.describe()
# Out:
#                SPX          GLD          USO          SLV      EUR/USD
# count  2290.000000  2290.000000  2290.000000  2290.000000  2290.000000
# mean   1654.315776   122.732875    31.842221    20.084997     1.283653
# std     519.111540    23.283346    19.523517     7.092566     0.131547
# min     676.530029    70.000000     7.960000     8.850000     1.039047
# 25%    1239.874969   109.725000    14.380000    15.570000     1.171313
# 50%    1551.434998   120.580002    33.869999    17.268500     1.303297
# 75%    2073.010070   132.840004    37.827501    22.882500     1.369971
# max    2872.870117   184.589996   117.480003    47.259998     1.598798

# %%
gold_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2290 entries, 0 to 2289
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2290 non-null   object
#  1   SPX      2290 non-null   float64
#  2   GLD      2290 non-null   float64
#  3   USO      2290 non-null   float64
#  4   SLV      2290 non-null   float64
#  5   EUR/USD  2290 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 107.5+ KB

# %%
gold_data.shape
# Out:
# (2290, 6)

# %%
gold_data.head()
# Out:
#        Date          SPX        GLD        USO     SLV   EUR/USD
# 0  1/2/2008  1447.160034  84.860001  78.470001  15.180  1.471692
# 1  1/3/2008  1447.160034  85.570000  78.370003  15.285  1.474491
# 2  1/4/2008  1411.630005  85.129997  77.309998  15.167  1.475492
# 3  1/7/2008  1416.180054  84.769997  75.500000  15.053  1.468299
# 4  1/8/2008  1390.189941  86.779999  76.059998  15.590  1.557099

# %%
gold_data.tail()
# Out:
#            Date          SPX         GLD      USO      SLV   EUR/USD
# 2285   5/8/2018  2671.919922  124.589996  14.0600  15.5100  1.186789
# 2286   5/9/2018  2697.790039  124.330002  14.3700  15.5300  1.184722
# 2287  5/10/2018  2723.070068  125.180000  14.4100  15.7400  1.191753
# 2288  5/14/2018  2730.129883  124.489998  14.3800  15.5600  1.193118
# 2289  5/16/2018  2725.780029  122.543800  14.4058  15.4542  1.182033

# %%
gold_data.isnull().sum()
# Out:
# Date       0
# SPX        0
# GLD        0
# USO        0
# SLV        0
# EUR/USD    0
# dtype: int64

# %%
sns.displot(data=gold_data,x='SPX')
# Out:
# C:\Users\Dipen-pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(gold_data,x='GLD')
# Out:
# <Axes: xlabel='GLD'>

# %%
df=gold_data.drop('Date',axis=1)

# %%
df
# Out:
#               SPX         GLD        USO      SLV   EUR/USD
# 0     1447.160034   84.860001  78.470001  15.1800  1.471692
# 1     1447.160034   85.570000  78.370003  15.2850  1.474491
# 2     1411.630005   85.129997  77.309998  15.1670  1.475492
# 3     1416.180054   84.769997  75.500000  15.0530  1.468299
# 4     1390.189941   86.779999  76.059998  15.5900  1.557099
# ...           ...         ...        ...      ...       ...
# 2285  2671.919922  124.589996  14.060000  15.5100  1.186789
# 2286  2697.790039  124.330002  14.370000  15.5300  1.184722
# 2287  2723.070068  125.180000  14.410000  15.7400  1.191753
# 2288  2730.129883  124.489998  14.380000  15.5600  1.193118
# 2289  2725.780029  122.543800  14.405800  15.4542  1.182033
#
# [2290 rows x 5 columns]

# %%
sns.pairplot(data=gold_data,hue='SLV')
# Out:
# C:\Users\Dipen-pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
n_col=gold_data.select_dtypes(include=['float64','int64'])
corr_matrix=n_col.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix,cmap='Blues',annot=True)
plt.title('Correlation')
# Out:
# Text(0.5, 1.0, 'Correlation')

# %%
print(corr_matrix['GLD'])
# Out:
# SPX        0.049345
# GLD        1.000000
# USO       -0.186360
# SLV        0.866632
# EUR/USD   -0.024375
# Name: GLD, dtype: float64

# %%
x=gold_data.drop(['Date','GLD'],axis=1)
y=gold_data['GLD']

# %%
print(x)
# Out:
#               SPX        USO      SLV   EUR/USD
# 0     1447.160034  78.470001  15.1800  1.471692
# 1     1447.160034  78.370003  15.2850  1.474491
# 2     1411.630005  77.309998  15.1670  1.475492
# 3     1416.180054  75.500000  15.0530  1.468299
# 4     1390.189941  76.059998  15.5900  1.557099
# ...           ...        ...      ...       ...
# 2285  2671.919922  14.060000  15.5100  1.186789
# 2286  2697.790039  14.370000  15.5300  1.184722
# 2287  2723.070068  14.410000  15.7400  1.191753
# 2288  2730.129883  14.380000  15.5600  1.193118
# 2289  2725.780029  14.405800  15.4542  1.182033
#
# [2290 rows x 4 columns]

# %%
print(y)
# Out:
# 0        84.860001
# 1        85.570000
# 2        85.129997
# 3        84.769997
# 4        86.779999
#            ...
# 2285    124.589996
# 2286    124.330002
# 2287    125.180000
# 2288    124.489998
# 2289    122.543800
# Name: GLD, Length: 2290, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
regressor=RandomForestRegressor(n_estimators=100)

# %%
regressor.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
#prediction on test data
test_data_prediction=regressor.predict(x_test)

# %%
print(test_data_prediction)
# Out:
# [168.53029954  81.87980004 115.96180031 127.65650082 120.65570118
#  154.92839781 150.19629815 126.13850046 117.49469871 125.88120088
#  116.50980114 172.78520078 141.60909857 167.81369796 115.20640006
#  117.53460041 139.02340272 170.27060072 159.84730336 155.09489976
#  155.25150033 125.24370017 176.57479893 156.80660371 125.21240029
#   93.83429975  77.47870008 120.53770005 119.12999948 167.48420009
#   88.11910066 125.05709984  91.27520067 117.77070036 121.1479997
#  136.25470131 115.53100122 115.37680068 146.35139997 106.71690087
#  104.49100263  87.09119787 126.43920063 117.51940024 152.93249911
#  119.68599983 108.38169997 108.01039862  93.05660082 127.17829742
#   74.66140044 113.60579943 121.51020021 111.20839964 119.00069867
#  120.29009962 158.82609993 169.02010119 146.97159695  85.83569889
#   94.29330022  86.81009926  90.68160026 119.02150053 126.38470044
#  127.59819988 169.92579982 122.26009966 117.30609884  98.42510034
# ...

# %%
#R squared error
error_score=metrics.r2_score(y_test,test_data_prediction)
print('R squared error:',error_score)
# Out:
# R squared error: 0.9883268535913525

# %%
y_test=list(y_test)

# %%
y_test
# Out:
# [168.020004,
#  81.230003,
#  112.32,
#  127.589996,
#  119.620003,
#  154.210007,
#  148.910004,
#  126.190002,
#  117.470001,
#  125.739998,
#  115.379997,
#  167.119995,
#  141.630005,
#  169.559998,
#  115.599998,
#  119.669998,
#  132.949997,
#  170.399994,
#  159.369995,
#  173.529999,
#  154.720001,
#  128.119995,
#  177.720001,
#  157.190002,
#  125.309998,
#  93.400002,
#  76.790001,
#  119.690002,
#  118.989998,
#  167.389999,
#  87.5,
#  124.980003,
#  91.230003,
#  115.489998,
#  120.949997,
#  133.809998,
#  116.690002,
#  113.809998,
#  133.580002,
#  105.970001,
#  105.120003,
#  87.959999,
#  126.82,
#  116.860001,
#  159.259995,
#  119.459999,
#  109.160004,
#  108.620003,
#  93.269997,
#  127.160004,
#  72.260002,
#  113.470001,
#  119.68,
#  109.139999,
#  119.309998,
#  120.050003,
#  159.889999,
#  161.490005,
#  146.740005,
#  85.809998,
#  93.709999,
#  85.550003,
#  91.029999,
#  118.489998,
#  126.449997,
#  126.980003,
#  171.699997,
#  122.400002,
# ...

# %%
plt.plot(y_test,color='blue',label='Actual Value')
plt.plot(test_data_prediction,color='green',label='Prediction Value')
plt.title('Actual Price Vs Predicted Price')
plt.xlabel('Number of values')
plt.ylabel('GLD Price')
plt.legend()
plt.show()
